import gymnasium as gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---

# %% [markdown]
# ## 1. DQN Implemetation

# %%
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        # Define a single hidden layer network
        self.fc1 = nn.Linear(state_dim, 128)  # First fully connected layer
        self.fc2 = nn.Linear(128, action_dim)  # Output layer

    def forward(self, s):
        # Pass the input through the layers with ReLU activation
        x = torch.relu(self.fc1(s))
        q = self.fc2(x)  # Output layer without activation
        return q

# %%
class DQNAgent:
    def __init__(self, state_size, action_size, device):
        self.state_size = state_size
        self.action_size = action_size
        self.device = device

        # Do not modify these hyper-parameters
        self.Epochs = 1000
        self.discount_factor = 0.98
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_min = 0.001
        self.batch_size = 256
        self.train_start = self.batch_size * 5
        self.memory = deque(maxlen=100000)

        # You can modify this depending on environments.
        self.epsilon_decay_rate = 0.995

        # Define and initialize your networks and optimizer
        self.q_network = QNetwork(state_size, action_size).to(device)
        self.target_network = QNetwork(state_size, action_size).to(device)
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=self.learning_rate)

        self.update_target_network()

    def update_target_network(self):
        self.target_network.load_state_dict(self.q_network.state_dict())

    def get_action(self, state, use_epsilon_greedy=True):
        if use_epsilon_greedy and np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
            q_values = self.q_network(state)
            return torch.argmax(q_values).item()

    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def get_samples(self, n):
        samples = random.sample(self.memory, n)
        states, actions, rewards, next_states, dones = zip(*samples)

        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).to(self.device)
        rewards = torch.FloatTensor(rewards).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).to(self.device)

        return states, actions, rewards, next_states, dones

    def epsilon_decay(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay_rate

    def train(self):
        if len(self.memory) < self.train_start:
            return None

        s_batch, a_batch, r_batch, s_next_batch, done_batch = self.get_samples(self.batch_size)

        q_values = self.q_network(s_batch).gather(1, a_batch.unsqueeze(1)).squeeze(1)
        next_q_values = self.target_network(s_next_batch).max(1)[0]
        target_q_values = r_batch + (self.discount_factor * next_q_values * (1 - done_batch))

        loss = nn.MSELoss()(q_values, target_q_values.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.epsilon_decay()

        return loss.item()

# %%
# Do not modify this cell
def evaluation(env, agent):
    done, episode_score, episode_steps = False, 0.0, 0

    state, _ = env.reset()
    for t in range(env._max_episode_steps):
        action = agent.get_action(state, use_epsilon_greedy=False)
        state_next, reward, done, time_truncation, _ = env.step(action)

        episode_score += reward
        episode_steps += 1

        state = state_next
        if done:
            break

    return episode_score, episode_steps

# %%
# experiments envs : "CartPole-v1", "Acrobot-v1", "MountainCar-v0"

env_name          = "CartPole-v1"

# %%
# Do not modify this cell

env               = gym.make(env_name)
state_size        = env.observation_space.shape[0]
action_size       = env.action_space.n
max_episode_steps = env._max_episode_steps
device            = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("state_size:{}, action_size:{}, max_episode_steps:{}, device:{} \n".format(state_size, action_size, max_episode_steps, device))

agent = DQNAgent(state_size, action_size, device)



episode_scores_list, episode_steps_list = [], []
for epoch in range(agent.Epochs):  # agent.Epochs = 1000

    state, _ = env.reset()
    for t in range(max_episode_steps):
        action = agent.get_action(state)
        state_next, reward, done, time_truncation, _ = env.step(action)

        agent.append_sample(state, action, reward, state_next, done)

        if len(agent.memory) >= agent.train_start:
            agent.train()

        state = state_next
        if done:
            state, _ = env.reset()

    agent.update_target_network()
    agent.epsilon_decay()

    episode_score, episode_steps = evaluation(env, agent)
Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:350, Episode_score:174.0, Episode_steps:174, epsilon:0.0009954703940636294
# Epoch:360, Episode_score:195.0, Episode_steps:195, epsilon:0.0009954703940636294
# Epoch:370, Episode_score:389.0, Episode_steps:389, epsilon:0.0009954703940636294
# Epoch:380, Episode_score:445.0, Episode_steps:445, epsilon:0.0009954703940636294
# Epoch:390, Episode_score:347.0, Episode_steps:347, epsilon:0.0009954703940636294
# Epoch:400, Episode_score:357.0, Episode_steps:357, epsilon:0.0009954703940636294
# Epoch:410, Episode_score:438.0, Episode_steps:438, epsilon:0.0009954703940636294
# Epoch:420, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:430, Episode_score:349.0, Episode_steps:349, epsilon:0.0009954703940636294
# Epoch:440, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:450, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:460, Episode_score:257.0, Episode_steps:257, epsilon:0.0009954703940636294
# Epoch:470, Episode_score:206.0, Episode_steps:206, epsilon:0.0009954703940636294
# Epoch:480, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:490, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:500, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:510, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:520, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:530, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:540, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:550, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:560, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:570, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:580, Episode_score:486.0, Episode_steps:486, epsilon:0.0009954703940636294
# Epoch:590, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:600, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:610, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:620, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:630, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:640, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:650, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:660, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:670, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:680, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:690, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:700, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:710, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:720, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:730, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:740, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:750, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:760, Episode_score:371.0, Episode_steps:371, epsilon:0.0009954703940636294
# Epoch:770, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:780, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:790, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:800, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:810, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:820, Episode_score:153.0, Episode_steps:153, epsilon:0.0009954703940636294
# Epoch:830, Episode_score:279.0, Episode_steps:279, epsilon:0.0009954703940636294
# Epoch:840, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:850, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:860, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:870, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:880, Episode_score:267.0, Episode_steps:267, epsilon:0.0009954703940636294
# Epoch:890, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:900, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:910, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:920, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:930, Episode_score:391.0, Episode_steps:391, epsilon:0.0009954703940636294
# Epoch:940, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:950, Episode_score:237.0, Episode_steps:237, epsilon:0.0009954703940636294
# Epoch:960, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:970, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:980, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:990, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294

# %%
# This cell provides basic evaluation score graph. You can add more plots.

plt.figure(figsize=(8, 3))

plt.subplot(1,2,1)
plt.plot(episode_scores_list)
plt.xlabel("Epochs")
plt.ylabel("Episode Scores")
plt.title("Episode Scores of {}".format(env_name))

plt.subplot(1,2,2)
plt.plot(episode_steps_list)
plt.xlabel("Epochs")
plt.ylabel("Episode Steps")
plt.title("Episode Steps of {}".format(env_name))

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Double DQN implemantation

# %%
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        # Define a single hidden layer network
        self.fc1 = nn.Linear(state_dim, 128)  # First fully connected layer
        self.fc2 = nn.Linear(128, action_dim)  # Output layer

    def forward(self, s):
        # Pass the input through the layers with ReLU activation
        x = torch.relu(self.fc1(s))
        q = self.fc2(x)  # Output layer without activation
        return q

# %%
class DoubleDQNAgent:
    def __init__(self, state_size, action_size, device):
        self.state_size         = state_size
        self.action_size        = action_size
        self.device             = device

        # Do not modify these hyper-parameters
        self.Epochs             = 1000
        self.discount_factor    = 0.98
        self.learning_rate      = 0.001  # learning rate for q function
        self.epsilon            = 1.0    # initial epsilon value
        self.epsilon_min        = 0.001  # minimum epsilon value
        self.batch_size         = 256
        self.train_start        = self.batch_size * 5
        self.memory             = deque(maxlen=100000)  # replay memory

        # You can modify this depending on environments.
        self.epsilon_decay_rate = 0.995   # decay rate

        # Define and initialize your networks and optimizer
        self.q_network = QNetwork(state_size, action_size).to(self.device)
        self.target_network = QNetwork(state_size, action_size).to(self.device)
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=self.learning_rate)
        self.update_target_network()


    def update_target_network(self):
        # implement target Q network update function
        self.target_network.load_state_dict(self.q_network.state_dict())


    def get_action(self, state, use_epsilon_greedy=True):
        if use_epsilon_greedy:
            if np.random.rand() <= self.epsilon:
                return random.randrange(self.action_size)
            else:
                state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
                q_values = self.q_network(state)
                return np.argmax(q_values.cpu().data.numpy())
        else:
            state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
            q_values = self.q_network(state)
            return np.argmax(q_values.cpu().data.numpy())

    def append_sample(self, state, action, reward, next_state, done):
        # implement storing function given (s,a,r,s',done) into the replay memory.
        self.memory.append((state, action, reward, next_state, done))
        
    def get_samples(self, n):
        # implement transition random sampling function from the replay memory,
        # and make the transiton to batch.
        minibatch = random.sample(self.memory, n)
        s_batch = np.array([sample[0] for sample in minibatch])
        a_batch = np.array([sample[1] for sample in minibatch])
        r_batch = np.array([sample[2] for sample in minibatch])
        s_next_batch = np.array([sample[3] for sample in minibatch])
        done_batch = np.array([sample[4] for sample in minibatch])
        # i.e.) s_batch : (batch_size, state_dim)
        
        return s_batch, a_batch, r_batch, s_next_batch, done_batch
        

    def epsilon_decay(self):
        # implement epsilon decaying function that
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay_rate
            
    def train(self):
        if len(self.memory) < self.train_start:
            return None

        s_batch, a_batch, r_batch, s_next_batch, done_batch = self.get_samples(self.batch_size)

        s_batch = torch.FloatTensor(s_batch).to(self.device)
        a_batch = torch.LongTensor(a_batch).unsqueeze(1).to(self.device)
        r_batch = torch.FloatTensor(r_batch).to(self.device)
        s_next_batch = torch.FloatTensor(s_next_batch).to(self.device)
        done_batch = torch.FloatTensor(done_batch).to(self.device)

        # Current Q values
        q_values = self.q_network(s_batch).gather(1, a_batch).squeeze(1)

        # Next Q values using Double DQN
        next_actions = self.q_network(s_next_batch).max(1)[1].unsqueeze(1)
        next_q_values = self.target_network(s_next_batch).gather(1, next_actions).squeeze(1)
        
        # Target Q values
        target_q_values = r_batch + (self.discount_factor * next_q_values * (1 - done_batch))

        # Loss
        loss = nn.MSELoss()(q_values, target_q_values.detach())

        # Optimize the model
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.epsilon_decay()

        # Optionally return statistics
        return loss.item()

# %%
# Do not modify this cell
def evaluation(env, agent):
    done, episode_score, episode_steps = False, 0.0, 0

    state, _ = env.reset()
    for t in range(env._max_episode_steps):
        action = agent.get_action(state, use_epsilon_greedy=False)
        state_next, reward, done, time_truncation, _ = env.step(action)

        episode_score += reward
        episode_steps += 1

        state = state_next
        if done:
            break

    return episode_score, episode_steps

# %%
# experiments envs : "CartPole-v1", "Acrobot-v1", "MountainCar-v0"

env_name          = "CartPole-v1"

# %%
# Do not modify this cell

env               = gym.make(env_name)
state_size        = env.observation_space.shape[0]
action_size       = env.action_space.n
max_episode_steps = env._max_episode_steps
device            = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("state_size:{}, action_size:{}, max_episode_steps:{}, device:{} \n".format(state_size, action_size, max_episode_steps, device))

agent = DoubleDQNAgent(state_size, action_size, device)



episode_scores_list, episode_steps_list = [], []
for epoch in range(agent.Epochs):  # agent.Epochs = 1000

    state, _ = env.reset()
    for t in range(max_episode_steps):
        action = agent.get_action(state)
        state_next, reward, done, time_truncation, _ = env.step(action)

        agent.append_sample(state, action, reward, state_next, done)

        if len(agent.memory) >= agent.train_start:
            agent.train()

        state = state_next
        if done:
            state, _ = env.reset()

    agent.update_target_network()
    agent.epsilon_decay()

    episode_score, episode_steps = evaluation(env, agent)
    episode_scores_list.append(episode_score)
    episode_steps_list.append(episode_steps)

    if epoch % 10 == 0:
        print("Epoch:{}, Episode_score:{}, Episode_steps:{}, epsilon:{}".format(epoch, episode_score, episode_steps, agent.epsilon))
# Out:
# state_size:4, action_size:2, max_episode_steps:500, device:cuda
#
# Epoch:0, Episode_score:9.0, Episode_steps:9, epsilon:0.995
# Epoch:10, Episode_score:249.0, Episode_steps:249, epsilon:0.0009954703940636294
# Epoch:20, Episode_score:187.0, Episode_steps:187, epsilon:0.0009954703940636294
# Epoch:30, Episode_score:173.0, Episode_steps:173, epsilon:0.0009954703940636294
# Epoch:40, Episode_score:168.0, Episode_steps:168, epsilon:0.0009954703940636294
# Epoch:50, Episode_score:216.0, Episode_steps:216, epsilon:0.0009954703940636294
# Epoch:60, Episode_score:250.0, Episode_steps:250, epsilon:0.0009954703940636294
# Epoch:70, Episode_score:186.0, Episode_steps:186, epsilon:0.0009954703940636294
# Epoch:80, Episode_score:186.0, Episode_steps:186, epsilon:0.0009954703940636294
# Epoch:90, Episode_score:186.0, Episode_steps:186, epsilon:0.0009954703940636294
# Epoch:100, Episode_score:182.0, Episode_steps:182, epsilon:0.0009954703940636294
# Epoch:110, Episode_score:178.0, Episode_steps:178, epsilon:0.0009954703940636294
# Epoch:120, Episode_score:195.0, Episode_steps:195, epsilon:0.0009954703940636294
# Epoch:130, Episode_score:177.0, Episode_steps:177, epsilon:0.0009954703940636294
# Epoch:140, Episode_score:178.0, Episode_steps:178, epsilon:0.0009954703940636294
# Epoch:150, Episode_score:185.0, Episode_steps:185, epsilon:0.0009954703940636294
# Epoch:160, Episode_score:203.0, Episode_steps:203, epsilon:0.0009954703940636294
# Epoch:170, Episode_score:249.0, Episode_steps:249, epsilon:0.0009954703940636294
# Epoch:180, Episode_score:184.0, Episode_steps:184, epsilon:0.0009954703940636294
# Epoch:190, Episode_score:189.0, Episode_steps:189, epsilon:0.0009954703940636294
# Epoch:200, Episode_score:206.0, Episode_steps:206, epsilon:0.0009954703940636294
# Epoch:210, Episode_score:192.0, Episode_steps:192, epsilon:0.0009954703940636294
# Epoch:220, Episode_score:219.0, Episode_steps:219, epsilon:0.0009954703940636294
# Epoch:230, Episode_score:191.0, Episode_steps:191, epsilon:0.0009954703940636294
# Epoch:240, Episode_score:195.0, Episode_steps:195, epsilon:0.0009954703940636294
# Epoch:250, Episode_score:289.0, Episode_steps:289, epsilon:0.0009954703940636294
# Epoch:260, Episode_score:265.0, Episode_steps:265, epsilon:0.0009954703940636294
# Epoch:270, Episode_score:202.0, Episode_steps:202, epsilon:0.0009954703940636294
# Epoch:280, Episode_score:197.0, Episode_steps:197, epsilon:0.0009954703940636294
# Epoch:290, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:300, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:310, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:320, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:330, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:340, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:350, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:360, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:370, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:380, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:390, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:400, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:410, Episode_score:375.0, Episode_steps:375, epsilon:0.0009954703940636294
# Epoch:420, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:430, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:440, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:450, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:460, Episode_score:267.0, Episode_steps:267, epsilon:0.0009954703940636294
# Epoch:470, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:480, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:490, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:500, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:510, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:520, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:530, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:540, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:550, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:560, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:570, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:580, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:590, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:600, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:610, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:620, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:630, Episode_score:179.0, Episode_steps:179, epsilon:0.0009954703940636294
# Epoch:640, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:650, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:660, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:670, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:680, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:690, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:700, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:710, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:720, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:730, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:740, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:750, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:760, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:770, Episode_score:232.0, Episode_steps:232, epsilon:0.0009954703940636294
# Epoch:780, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:790, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:800, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:810, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:820, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:830, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:840, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:850, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:860, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:870, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:880, Episode_score:129.0, Episode_steps:129, epsilon:0.0009954703940636294
# Epoch:890, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:900, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:910, Episode_score:197.0, Episode_steps:197, epsilon:0.0009954703940636294
# Epoch:920, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:930, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:940, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:950, Episode_score:336.0, Episode_steps:336, epsilon:0.0009954703940636294
# Epoch:960, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294
# Epoch:970, Episode_score:375.0, Episode_steps:375, epsilon:0.0009954703940636294
# Epoch:980, Episode_score:394.0, Episode_steps:394, epsilon:0.0009954703940636294
# Epoch:990, Episode_score:500.0, Episode_steps:500, epsilon:0.0009954703940636294

# %%
# This cell provides basic evaluation score graph. You can add more plots.

plt.figure(figsize=(8, 3))

plt.subplot(1,2,1)
plt.plot(episode_scores_list)
plt.xlabel("Epochs")
plt.ylabel("Episode Scores")
plt.title("Episode Scores of {}".format(env_name))

plt.subplot(1,2,2)
plt.plot(episode_steps_list)
plt.xlabel("Epochs")
plt.ylabel("Episode Steps")
plt.title("Episode Steps of {}".format(env_name))

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Additional Implementation

# %%
import os
import gymnasium as gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
class ActorCriticNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCriticNetwork, self).__init__()
        # Define actor network
        self.actor_fc1 = nn.Linear(state_dim, 128)
        self.actor_fc2 = nn.Linear(128, action_dim)
        # Define critic network
        self.critic_fc1 = nn.Linear(state_dim, 128)
        self.critic_fc2 = nn.Linear(128, 1)

    def forward(self, state):
        # Actor forward pass
        actor_x = torch.relu(self.actor_fc1(state))
        action_probs = torch.softmax(self.actor_fc2(actor_x), dim=-1)
        # Critic forward pass
        critic_x = torch.relu(self.critic_fc1(state))
        state_value = self.critic_fc2(critic_x)
        return action_probs, state_value

# %%
class PPOAgent:
    def __init__(self, state_size, action_size, device):
        self.state_size = state_size
        self.action_size = action_size
        self.device = device

        # PPO hyperparameters
        self.Epochs = 1000
        self.epsilon = 0.2
        self.value_coef = 0.5
        self.entropy_coef = 0.01
        self.learning_rate = 0.001
        self.batch_size = 256
        
        # Initialize actor-critic networks
        self.actor_critic = ActorCriticNetwork(state_size, action_size).to(device)
        self.optimizer = optim.Adam(self.actor_critic.parameters(), lr=self.learning_rate)

    def get_action(self, state):
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        action_probs, _ = self.actor_critic(state)
        action_probs = action_probs.cpu().detach().numpy().squeeze()
        action = np.random.choice(np.arange(self.action_size), p=action_probs)
        return action

    def ppo_iter(self, states, actions, log_probs, returns, advantage):
        batch_size = len(states)
        for _ in range(batch_size // self.batch_size):
            rand_ids = np.random.randint(0, batch_size, self.batch_size)
            yield (
                states[rand_ids],
                actions[rand_ids],
                log_probs[rand_ids],
                returns[rand_ids],
                advantage[rand_ids]
            )

    def ppo_update(self, states, actions, log_probs, returns, advantages):
        for _ in range(self.Epochs):
            for state, action, old_log_prob, return_, advantage in self.ppo_iter(states, actions, log_probs, returns, advantages):
                action_probs, state_value = self.actor_critic(state)
                dist = torch.distributions.Categorical(action_probs)
                entropy = dist.entropy().mean()
                new_log_prob = dist.log_prob(action)

                ratio = (new_log_prob - old_log_prob).exp()
                surr1 = ratio * advantage
                surr2 = torch.clamp(ratio, 1.0 - self.epsilon, 1.0 + self.epsilon) * advantage

                actor_loss = -torch.min(surr1, surr2).mean()
                critic_loss = nn.MSELoss()(state_value, return_)

                loss = actor_loss + self.value_coef * critic_loss - self.entropy_coef * entropy

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

# %%
def evaluation(env, agent):
    done, episode_score, episode_steps = False, 0.0, 0

    state = env.reset()
    while not done:
        action = agent.get_action(state)
        state_next, reward, done, _ = env.step(action)

        episode_score += reward
        episode_steps += 1

        state = state_next

    return episode_score, episode_steps

# %%
# experiments envs : "CartPole-v1", "Acrobot-v1", "MountainCar-v0"

env_name = "CartPole-v1"

# %%
# Do not modify this cell

env = gym.make(env_name)
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("state_size:{}, action_size:{}, device:{} \n".format(state_size, action_size, device))

agent = PPOAgent(state_size, action_size, device)

episode_scores_list, episode_steps_list = [], []
for epoch in range(agent.Epochs):
    states, actions, log_probs, rewards, dones, values = [], [], [], [], [], []

    state = env.reset()
    done = False
    while not done:
        action = agent.get_action(state)
        state_next, reward, done, _ = env.step(action)

        states.append(state)
        actions.append(action)
        rewards.append(reward)
        dones.append(done)

        state = state_next

    states = torch.FloatTensor(states).to(device)
    actions = torch.LongTensor(actions).to(device)
    rewards = torch.FloatTensor(rewards).to(device)
    dones = torch.FloatTensor(dones).to(device)

    _, state_values = agent.actor_critic(states)
    advantages = rewards - state_values.detach()

    agent.ppo_update(states, actions, log_probs, rewards, advantages)

    episode_score, episode_steps = evaluation(env, agent)
    episode_scores_list.append(episode_score)
    episode_steps_list.append(episode_steps)

    if epoch % 10 == 0:
        print("Epoch:{}, Episode_score:{}, Episode_steps:{}".format(epoch, episode_score, episode_steps))
# Out:
# state_size:4, action_size:2, device:cuda
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 19
#      17 done = False
#      18 while not done:
# ---> 19     action = agent.get_action(state)
#      20     state_next, reward, done, _ = env.step(action)
#      22     states.append(state)
#
# Cell In[5], line 20, in PPOAgent.get_action(self, state)
#      19 def get_action(self, state):
# ---> 20     state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
#      21     action_probs, _ = self.actor_critic(state)
#      22     action_probs = action_probs.cpu().detach().numpy().squeeze()
#
# ValueError: expected sequence of length 4 at dim 1 (got 0)

# %%
# This cell provides basic evaluation score graph. You can add more plots.

plt.figure(figsize=(8, 3))

plt.subplot(1,2,1)
plt.plot(episode_scores_list)
plt.xlabel("Epochs")
plt.ylabel("Episode Scores")
plt.title("Episode Scores of {}".format(env_name))

plt.subplot(1,2,2)
plt.plot(episode_steps_list)
plt.xlabel("Epochs")
plt.ylabel("Episode Steps")
plt.title("Episode Steps of {}".format(env_name))

plt.show()
